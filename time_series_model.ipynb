# %% [markdown]
# <a href="https://colab.research.google.com/github/loftyiceberg/Pyspark-Capstone-Project/blob/Nikhita/time_series_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# In order to be able to see all the rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
timeseries_df = pd.read_csv("/content/drive/MyDrive/Colabdata/timeseries_df.csv")

# %%
timeseries_df.head()
# Out:
#    Unnamed: 0  Time_period   Stunting  Severe_Stunting  Underweight  \
# 0           0         1986  28.316667         9.016667    19.200000
# 1           1         1987  34.066667        14.880952    18.626316
# 2           2         1988  34.166667        13.787500    13.952632
# 3           3         1989  28.655556         9.283333    15.540000
# 4           4         1990  33.188235        12.800000    17.852381
#
#    Severe_Underweight   Wasting  Severe_Wasting  Overweight     Obese
# 0            3.141667  7.066667        1.700000    4.980000  0.950000
# 1            6.347619  5.441176        1.466667    2.556000  0.442857
# 2            4.279167  4.710526        0.950000    4.216000  0.862500
# 3            3.266667  6.175000        1.172727    5.785714  0.991667
# 4            4.500000  6.341176        1.875000    5.335714  1.508333

# %%
timeseries_df.drop("Unnamed: 0", axis=1,inplace=True)

# %%
timeseries_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Time_period         37 non-null     int64
#  1   Stunting            37 non-null     float64
#  2   Severe_Stunting     37 non-null     float64
#  3   Underweight         37 non-null     float64
#  4   Severe_Underweight  37 non-null     float64
#  5   Wasting             37 non-null     float64
#  6   Severe_Wasting      37 non-null     float64
#  7   Overweight          37 non-null     float64
#  8   Obese               37 non-null     float64
# dtypes: float64(8), int64(1)
# memory usage: 2.7 KB

# %%
#plotting the annual severe wasting distribution trend

plt.figure(figsize = [20,5])
sns.lineplot(data = timeseries_df, x = 'Time_period', y = 'Stunting', marker = 'o', color ='r')
plt.title('Global Annual Stunting Trend', fontsize = 20)
plt.xticks(timeseries_df['Time_period'])
plt.savefig('StuntingTrend', bbox_inches = 'tight', dpi = 300)

# %%
#plotting the annual severe wasting distribution trend

plt.figure(figsize = [20,5])
sns.lineplot(data = timeseries_df, x = 'Time_period', y = 'Severe_Stunting', marker = 'o', color ='m')
plt.title('Global Annual Severe Stunting Trend', fontsize = 20)
plt.xticks(timeseries_df['Time_period'])
plt.savefig('SevereStuntingTrend', bbox_inches = 'tight', dpi = 300)

# %%
#plotting the annual severe wasting distribution trend

plt.figure(figsize = [20,5])
sns.lineplot(data = timeseries_df, x = 'Time_period', y = 'Underweight', marker = 'o', color ='g')
plt.title('Global Annual Underweight Trend', fontsize = 20)
plt.xticks(timeseries_df['Time_period'])
plt.savefig('UnderweightTrend', bbox_inches = 'tight', dpi = 300)

# %%
#plotting the annual severe wasting distribution trend

plt.figure(figsize = [20,5])
sns.lineplot(data = timeseries_df, x = 'Time_period', y = 'Severe_Underweight', marker = 'o', color ='c')
plt.title('Global Annual Severe Underweight Trend', fontsize = 20)
plt.xticks(timeseries_df['Time_period'])
plt.savefig('SevereUnderweightTrend', bbox_inches = 'tight', dpi = 300)

# %%
#plotting the annual severe wasting distribution trend

plt.figure(figsize = [20,5])
sns.lineplot(data = timeseries_df, x = 'Time_period', y = 'Wasting', marker = 'o', color ='k')
plt.title('Global Annual Wasting Trend', fontsize = 20)
plt.xticks(timeseries_df['Time_period'])
plt.savefig('SevereWastingTrend', bbox_inches = 'tight', dpi = 300)

# %%
#plotting the annual severe wasting distribution trend

plt.figure(figsize = [20,5])
sns.lineplot(data = timeseries_df, x = 'Time_period', y = 'Severe_Wasting', marker = 'o', color ='y')
plt.title('Global Annual Severe Wasting Trend', fontsize = 20)
plt.xticks(timeseries_df['Time_period'])
plt.savefig('SevereWastingTrend', bbox_inches = 'tight', dpi = 300)

# %%
#plotting the annual severe wasting distribution trend

plt.figure(figsize = [20,5])
sns.lineplot(data = timeseries_df, x = 'Time_period', y = 'Overweight', marker = 'o', color ='tan')
plt.title('Global Annual Overweight Trend', fontsize = 20)
plt.xticks(timeseries_df['Time_period'])
plt.savefig('OverweightTrend', bbox_inches = 'tight', dpi = 300)

# %%
#plotting the annual severe wasting distribution trend

plt.figure(figsize = [20,5])
sns.lineplot(data = timeseries_df, x = 'Time_period', y = 'Obese', marker = 'o', color ='navy')
plt.title('Global Annual Obesity Trend', fontsize = 20)
plt.xticks(timeseries_df['Time_period'])
plt.savefig('ObesityTrend', bbox_inches = 'tight', dpi = 300)

# %%
timeseries_df.Time_period = timeseries_df.Time_period.astype(str)

# %%
timeseries_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Time_period         37 non-null     object
#  1   Stunting            37 non-null     float64
#  2   Severe_Stunting     37 non-null     float64
#  3   Underweight         37 non-null     float64
#  4   Severe_Underweight  37 non-null     float64
#  5   Wasting             37 non-null     float64
#  6   Severe_Wasting      37 non-null     float64
#  7   Overweight          37 non-null     float64
#  8   Obese               37 non-null     float64
# dtypes: float64(8), object(1)
# memory usage: 2.7+ KB

# %%
# Converting FullDate column into DateTime
timeseries_df.Time_period = pd.to_datetime(timeseries_df["Time_period"])

# %%
timeseries_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Time_period         37 non-null     datetime64[ns]
#  1   Stunting            37 non-null     float64
#  2   Severe_Stunting     37 non-null     float64
#  3   Underweight         37 non-null     float64
#  4   Severe_Underweight  37 non-null     float64
#  5   Wasting             37 non-null     float64
#  6   Severe_Wasting      37 non-null     float64
#  7   Overweight          37 non-null     float64
#  8   Obese               37 non-null     float64
# dtypes: datetime64[ns](1), float64(8)
# memory usage: 2.7 KB

# %%
timeseries_df
# Out:
#    Time_period   Stunting  Severe_Stunting  Underweight  Severe_Underweight  \
# 0   1986-01-01  28.316667         9.016667    19.200000            3.141667
# 1   1987-01-01  34.066667        14.880952    18.626316            6.347619
# 2   1988-01-01  34.166667        13.787500    13.952632            4.279167
# 3   1989-01-01  28.655556         9.283333    15.540000            3.266667
# 4   1990-01-01  33.188235        12.800000    17.852381            4.500000
# 5   1991-01-01  33.764103        15.386667    16.961905            5.770370
# 6   1992-01-01  41.665217        19.443590    21.496078            8.238095
# 7   1993-01-01  33.458696        12.855556    19.088636            5.463889
# 8   1994-01-01  32.228205        12.700000    18.712903            5.214815
# 9   1995-01-01  31.466667        13.610000    16.093333            4.746667
# 10  1996-01-01  33.033333        15.829167    16.824074            7.206250
# 11  1997-01-01  36.019565        18.023077    21.221053            8.774359
# 12  1998-01-01  32.441071        14.114583    15.061702            5.531373
# 13  1999-01-01  30.768333        13.880392    15.550000            5.364815
# 14  2000-01-01  30.716667        13.918667    16.602632            5.985417
# 15  2001-01-01  30.528000        14.553333    17.714286            5.948889
# 16  2002-01-01  27.011475        12.096491    13.275410            4.307018
# 17  2003-01-01  28.692982        12.250980    16.298182            5.064815
# 18  2004-01-01  25.381250        11.373333    12.656944            4.202778
# 19  2005-01-01  26.464045        11.627778    12.346591            3.989247
# 20  2006-01-01  25.942500        11.139316    13.511966            4.550450
# 21  2007-01-01  26.844944        11.163218    14.965432            4.413793
# 22  2008-01-01  24.163889         9.473437    11.587879            3.218033
# 23  2009-01-01  28.201136        11.123171    14.388889            3.787805
# 24  2010-01-01  27.879412        11.517647    14.218627            4.429293
# 25  2011-01-01  26.575532        10.672165    15.568293            4.540206
# 26  2012-01-01  19.688393         6.834821    10.530909            2.630275
# 27  2013-01-01  25.844304        11.261644    15.211688            4.687671
# 28  2014-01-01  23.230714         8.911765    13.706015            3.672180
# 29  2015-01-01  27.251389         9.812676    15.619118            4.177465
# 30  2016-01-01  20.180000         7.007692    11.582759            2.964773
# 31  2017-01-01  20.074026         6.421053    11.998529            2.673684
# 32  2018-01-01  22.707627         8.046154    11.623636            3.098246
# 33  2019-01-01  18.525688         6.038739     8.896842            2.198198
# 34  2020-01-01  23.482540         8.270312    13.571930            3.289062
# 35  2021-01-01  20.125000         6.629167    12.725581            3.011111
# 36  2022-01-01  31.341667        11.320833    20.312500            5.279167
#
#      Wasting  Severe_Wasting  Overweight     Obese
# 0   7.066667        1.700000    4.980000  0.950000
# 1   5.441176        1.466667    2.556000  0.442857
# 2   4.710526        0.950000    4.216000  0.862500
# 3   6.175000        1.172727    5.785714  0.991667
# 4   6.341176        1.875000    5.335714  1.508333
# 5   6.348718        1.964516    6.072222  1.640741
# 6   7.725000        2.602632    5.552381  1.702564
# 7   8.514286        2.396970    4.425000  1.233333
# 8   7.875862        2.277778    4.803030  1.074074
# 9   6.670455        1.939286    8.476190  2.951515
# 10  6.652727        1.992500    6.021667  1.780392
# 11  9.202632        3.212903    5.304444  1.828205
# 12  5.334000        1.437209    6.546667  2.064815
# 13  6.632000        2.130952    6.305172  1.654902
# 14  7.673077        2.746667    7.190728  2.368027
# 15  7.632075        2.581633    6.669231  2.320833
# 16  5.480645        1.972881    7.379365  2.124561
# 17  6.298214        2.205882    7.756140  2.527778
# 18  6.217333        2.168571    7.130769  1.990278
# 19  5.946591        2.138372    9.379348  3.137778
# 20  7.219658        2.550435    8.258974  2.911712
# 21  7.403704        2.312658    6.608140  2.238667
# 22  4.847761        1.346774    6.664789  1.896667
# 23  6.073077        1.736364    5.892105  1.932787
# 24  6.651456        2.186408    6.555882  2.091919
# 25  7.002439        2.054321    5.510000  1.589655
# 26  5.608182        1.399083    6.823853  1.929412
# 27  6.456410        2.261111    6.630000  2.053165
# 28  6.310526        1.769231    5.753030  1.384874
# 29  6.918841        2.028986    5.425333  1.517568
# 30  5.283721        1.222892    5.697872  1.460227
# 31  6.021429        1.582609    5.327160  1.372368
# 32  4.600926        1.162037    5.710619  1.513462
# 33  4.408421        1.125263    6.305505  1.915179
# 34  5.370690        1.287931    5.310937  1.321311
# 35  5.888372        1.360465    3.922917  1.057143
# 36  7.722222        1.416667    2.020000  0.250000

# %%
timeseries_df.set_index( "Time_period" , inplace= True )

# %%
from prophet import Prophet

# %%
def create_fp_df(burden):
  fp_df = timeseries_df[[burden]].copy()
  fp_df.reset_index(inplace = True)
  fp_df.rename(columns = {'Time_period':'ds'}, inplace = True)
  fp_df.rename(columns = {burden:'y'}, inplace = True)
  return fp_df

# %%
fp_df = create_fp_df('Stunting')

# %%
# Initialize the Model
model=Prophet()

# %%
model.fit(fp_df)
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpzamr3iew/rfuvu009.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpzamr3iew/jkwofp9s.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=61354', 'data', 'file=/tmp/tmpzamr3iew/rfuvu009.json', 'init=/tmp/tmpzamr3iew/jkwofp9s.json', 'output', 'file=/tmp/tmpzamr3iew/prophet_modele0o33cim/prophet_model-20230827172207.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 17:22:07 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:22:07 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
# Predicting next 5 years
future_dates=model.make_future_dataframe(5, freq='A')

# %%
future_dates.tail()
# Out:
#            ds
# 37 2022-12-31
# 38 2023-12-31
# 39 2024-12-31
# 40 2025-12-31
# 41 2026-12-31

# %%
prediction=model.predict(future_dates)

# %%
### plot the predicted projection
model.plot(prediction,include_legend=True)
plt.title("Stunting")
# Out:
# Text(0.5, 1.0, 'Stunting')

# %%
fp_df = create_fp_df('Severe_Stunting')

# %%
# Initialize the Model
model=Prophet()

# %%
model.fit(fp_df)
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpzamr3iew/8gphaf6v.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpzamr3iew/6qngjedr.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=71638', 'data', 'file=/tmp/tmpzamr3iew/8gphaf6v.json', 'init=/tmp/tmpzamr3iew/6qngjedr.json', 'output', 'file=/tmp/tmpzamr3iew/prophet_modelaflvyk4o/prophet_model-20230827172210.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 17:22:10 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:22:10 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
prediction=model.predict(future_dates)

# %%
### plot the predicted projection
model.plot(prediction,include_legend=True)
plt.title("Severe Stunting")
# Out:
# Text(0.5, 1.0, 'Severe Stunting')

# %%
fp_df = create_fp_df('Underweight')

# %%
# Initialize the Model
model=Prophet()

# %%
model.fit(fp_df)
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpzamr3iew/uo9jpqwe.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpzamr3iew/g9s7bmh5.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=72258', 'data', 'file=/tmp/tmpzamr3iew/uo9jpqwe.json', 'init=/tmp/tmpzamr3iew/g9s7bmh5.json', 'output', 'file=/tmp/tmpzamr3iew/prophet_modelo1dqftp2/prophet_model-20230827172212.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 17:22:12 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:22:13 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
prediction=model.predict(future_dates)

# %%
### plot the predicted projection
model.plot(prediction,include_legend=True)
plt.title("Underweight")
# Out:
# Text(0.5, 1.0, 'Underweight')

# %%
fp_df = create_fp_df('Severe_Underweight')

# %%
# Initialize the Model
model=Prophet()

# %%
model.fit(fp_df)
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpzamr3iew/9xpdflfq.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpzamr3iew/5583no3z.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=88499', 'data', 'file=/tmp/tmpzamr3iew/9xpdflfq.json', 'init=/tmp/tmpzamr3iew/5583no3z.json', 'output', 'file=/tmp/tmpzamr3iew/prophet_modelcsfoztqy/prophet_model-20230827172215.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 17:22:15 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:22:15 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
prediction=model.predict(future_dates)

# %%
### plot the predicted projection
model.plot(prediction,include_legend=True)
plt.title("Severe Underweight")
# Out:
# Text(0.5, 1.0, 'Severe Underweight')

# %%
fp_df = create_fp_df('Wasting')

# %%
# Initialize the Model
model=Prophet()

# %%
model.fit(fp_df)
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpzamr3iew/r5ujzdi9.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpzamr3iew/ma8hl7vv.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=16077', 'data', 'file=/tmp/tmpzamr3iew/r5ujzdi9.json', 'init=/tmp/tmpzamr3iew/ma8hl7vv.json', 'output', 'file=/tmp/tmpzamr3iew/prophet_model8dj5j3oo/prophet_model-20230827172216.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 17:22:16 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:22:16 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
prediction=model.predict(future_dates)

# %%
### plot the predicted projection
model.plot(prediction,include_legend=True)
plt.title("Wasting")
# Out:
# Text(0.5, 1.0, 'Wasting')

# %%
fp_df = create_fp_df('Severe_Wasting')

# %%
# Initialize the Model
model=Prophet()

# %%
model.fit(fp_df)
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpzamr3iew/u0v1g452.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpzamr3iew/5siuzam2.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=20939', 'data', 'file=/tmp/tmpzamr3iew/u0v1g452.json', 'init=/tmp/tmpzamr3iew/5siuzam2.json', 'output', 'file=/tmp/tmpzamr3iew/prophet_model6tniwmn_/prophet_model-20230827172217.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 17:22:17 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:22:17 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
prediction=model.predict(future_dates)

# %%
### plot the predicted projection
model.plot(prediction,include_legend=True)
plt.title("Severe Wasting")
# Out:
# Text(0.5, 1.0, 'Severe Wasting')

# %%
fp_df = create_fp_df('Overweight')

# %%
# Initialize the Model
model=Prophet()

# %%
model.fit(fp_df)
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpzamr3iew/337njwe3.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpzamr3iew/qs5nsqql.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=29172', 'data', 'file=/tmp/tmpzamr3iew/337njwe3.json', 'init=/tmp/tmpzamr3iew/qs5nsqql.json', 'output', 'file=/tmp/tmpzamr3iew/prophet_modeldywj9d2w/prophet_model-20230827172218.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 17:22:18 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:22:18 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
prediction=model.predict(future_dates)

# %%
### plot the predicted projection
model.plot(prediction,include_legend=True)
plt.title("Overweight")
# Out:
# Text(0.5, 1.0, 'Overweight')

# %%
fp_df = create_fp_df('Obese')

# %%
# Initialize the Model
model=Prophet()

# %%
model.fit(fp_df)
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpzamr3iew/ileu90e7.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpzamr3iew/6csegnlw.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=35452', 'data', 'file=/tmp/tmpzamr3iew/ileu90e7.json', 'init=/tmp/tmpzamr3iew/6csegnlw.json', 'output', 'file=/tmp/tmpzamr3iew/prophet_model_yd778v0/prophet_model-20230827172219.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 17:22:19 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:22:19 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
prediction=model.predict(future_dates)

# %%
### plot the predicted projection
model.plot(prediction,include_legend=True)
plt.title("Obese")
# Out:
# Text(0.5, 1.0, 'Obese')
